# %% [markdown]
# # Mathletics

# %% [markdown]
# ## Chapter 1:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_teams = pd.read_csv('baseballdatabank-2022.2/core/Teams.csv')

# %%
df_teams['ActWin%'] = df_teams['W'] / (df_teams['W'] + df_teams['L'])
df_teams['ExpWin%'] = (df_teams['R'] ** 2) / ((df_teams['R'] ** 2) + (df_teams['RA'] ** 2))

# %%
df_teams
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome    W    L  ...  \
# 0       1871  NaN    BS1      BNA   NaN     3   31    NaN   20   10  ...
# 1       1871  NaN    CH1      CNA   NaN     2   28    NaN   19    9  ...
# 2       1871  NaN    CL1      CFC   NaN     8   29    NaN   10   19  ...
# 3       1871  NaN    FW1      KEK   NaN     7   19    NaN    7   12  ...
# 4       1871  NaN    NY2      NNA   NaN     5   33    NaN   16   17  ...
# ...      ...  ...    ...      ...   ...   ...  ...    ...  ...  ...  ...
# 2980    2021   NL    SLN      STL     C     2  162   81.0   90   72  ...
# 2981    2021   AL    TBA      TBD     E     1  162   81.0  100   62  ...
# 2982    2021   AL    TEX      TEX     W     5  162   81.0   60  102  ...
# 2983    2021   AL    TOR      TOR     E     4  162   80.0   91   71  ...
# 2984    2021   NL    WAS      WSN     E     5  162   81.0   65   97  ...
#
#                          name                          park attendance  BPF  \
# 0        Boston Red Stockings           South End Grounds I        NaN  103
# 1     Chicago White Stockings       Union Base-Ball Grounds        NaN  104
# 2      Cleveland Forest Citys  National Association Grounds        NaN   96
# 3        Fort Wayne Kekiongas                Hamilton Field        NaN  101
# 4            New York Mutuals      Union Grounds (Brooklyn)        NaN   90
# ...                       ...                           ...        ...  ...
# 2980      St. Louis Cardinals             Busch Stadium III  2102530.0   92
# 2981           Tampa Bay Rays               Tropicana Field   761072.0   92
# 2982            Texas Rangers              Globe Life Field  2110258.0   99
# 2983        Toronto Blue Jays                  Sahlen Field   805901.0  102
# 2984     Washington Nationals                Nationals Park  1465543.0   95
#
#       PPF  teamIDBR  teamIDlahman45  teamIDretro   ActWin%   ExpWin%
# 0      98       BOS             BS1          BS1  0.666667  0.636558
# 1     102       CHI             CH1          CH1  0.678571  0.610939
# 2     100       CLE             CL1          CL1  0.344828  0.347769
# 3     107       KEK             FW1          FW1  0.368421  0.241191
# 4      88       NYU             NY2          NY2  0.484848  0.482120
# ...   ...       ...             ...          ...       ...       ...
# 2980   92       STL             SLN          SLN  0.555556  0.524658
# 2981   91       TBR             TBA          TBA  0.617284  0.634102
# 2982  101       TEX             TEX          TEX  0.370370  0.370313
# 2983  101       TOR             TOR          TOR  0.561728  0.619515
# 2984   96       WSN             MON          WAS  0.401235  0.438063
#
# [2985 rows x 50 columns]
